# %% [markdown]
# **In our daily lives we view many products and review them if we like or dislike the same on vaious platforms like the Amazon,
# Flipkart and many more. These reviews extraction helps the platform to check the sentiments attached to the product and the
# ratings help the brands to pitch in the product for various offers they can offer depending on the popularity**
#
# **In this notebook/ code we will try to extract the reviews from Amazon and try to checke the sentiment analysis for the same
# and frequency distribution and other NLP techniques for the analysis.**

# %%
# let us start with importing the dependencies for the analysis 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from bs4 import BeautifulSoup as bs
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# We will now extract the reviews for a particular product from "Amazon.in",
# say for "Iphone 12" (ideally selecting the product with more reviews)

# creating an empty list
ipr = []

'''defining a for loop to extract reviews from the amazon page for "Iphone12"
    for 20 pages. Say one page has 10 reviews, we will be able to extract 200 reviews'''
for i in range(1,21):
    ip = []
    url = "https://www.amazon.in/Apple-iPhone-13-256GB-Product/product-reviews/B09G9HDN4Q/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber="+str(i)
    response = requests.get(url) # getting the url and helping extract reviews from it
    soup = bs(response.content, "html.parser") #help extract the url from html
    reviews = soup.find_all("span", attrs = {"class", "a-size-base review-text review-text-content"}) # helps extract the particular data from the mentioned tags in the html code
    for i in range(len(reviews)):
        ip.append(reviews[i].text)
    # this helps extract the reviews to go page by page and extract them by appending them
    ipr = ipr + ip

# %%
# checking the extracted text
ipr
# Out:
# ['\n\n  This product is duplicate of iPhone 12 only camera design changed. Very low quality of this product Buy Samsung mobile phone\n\n',
#  '\n\n  You should be a bigggggg bot to buy this phoneYou could get iPhone 12 Pro that’s the best 😂\n\n',
#  "\n\n  Iphone 13(blue), Outlook looks good but not attractive, looks dim. After usage of 20min, I can see fingerprints all over the phone. Cinematic video features looks great, can't use Iphone 13 charging cable with other iphone adapters. Finally my first iPhone experience is average.\n\n",
#  '\n\n  There was a hairline scratch on the screen which is not clearly visible directly. When we tried contacting Amazon for the replacement, they asked us to connect to apple and when connected to apple, they asked to connect with Amazon. Blame game begins and we end up paying the price. Awfull service. I am going to tag on the social media both Amazon and apple. Such a big scam\n\n',
#  "\n\n  Ignore the negative comments made by amateurs.Reasons for upgrade :1. Camera: Bigger camera aperture, OIS, cinematic mode. Low light pictures are outstanding as you can see the 2nd picture of the flower taken at night. Also some of the pictures during daylight for reference.2. Battery: Apple has really done a good job in battery management. It's giving a good battery back up.3. Processor: New A15 processor and better performance.4. Software: This is the usual strong point of any iPhone with iOS.5. Storage: Not to forget you’re now getting 128 gigs as base storage compared to 64 gigs last year on base model price.Who should buy this phone:1. If you're already using an iPhone 12 don't bother to upgrade. Wait for next year release.2. Those who are using iPhone 10 or previous versions can surely feel much of a difference.3. Price gap: Iphone 12 is 70,000 INR with no offers at present. Iphone 13 with 6000 discount on HDFC Cards makes the actual price around 74000. It makes no sense to save 4000 and buy an year old device iPhone 12 if you’re upgrading from iPhone 10 or previous versions.4. iPhone 12 purchase will only make sense compared to iPhone 13 if it's price gets reduced  to 55000.Customer Expectations:1. At least an always on display.2. On display fingerprint scanner.3. A 90hz refresh rate if not 120hz for iPhone 13 model. In India we are paying a lot for base models.\n\n",
#  '\n\n  Just but iphone 12!It’s not worth the money!Unless ur from BJP or something where you’re full with corrupt money, then go ahead.\n\n',
#  '\n\n  Same as I phone 12 😑. Who so ever is reading this review I suggest go for I phone 12\n\n',
#  '\n\n  i am poor and i cant afford it lmao xdxdxdxdxd so if you have money to flex buy it i am bored thats why i am writing this review while drinking coffee i have my chemistry exam on  manday and cant study mole concept and got bored thats why i came here to write this review if you read this review til here very good you justt wasted your time now go and do something productive :)\n\n',
#  '\n\n  Oneplus 7 to IPhone 13The UI and feel which iphone gives is mind blowing.\n\n',
#  '\n\n  I do not have money that I can get a phone but I have a dream to get a phone which will definitely be fulfilled one day\n\n',
#  '\n\n  I’ve been using iPhone 6s for almost last 6 years. The only problem I ever faced in its entire lifespan was the battery life. And Apple has finally broken that. Apart from amazing user experience, camera, and all that is great about iPhone, the battery life of iPhone 13 is simply awesome. Do not doubt for a second if you want to upgrade your phone. Jus go for it.\n\n',
#  '\n\n  May not be the best one to upgrade to, but I absolutely loved this phone as a first time iPhone user. Battery and Camera are better than expected.\n\n',
#  '\n\n  Assuming you’re starting with a good foundation, I think the list of what really makes a big difference in phone upgrades is actually short. The first thing on the list is improved battery life. The second is an improved camera.This Two Factor really matter in our day to day life and regular useNo any other things are improved like a screen and chip performanceOverall Soft Update for 12\n\n',
#  "\n\n  Apple Marketing has done quite a good job month after month to keep people on their toes with their new launches where there is nothing great about this phone. I have been on Android for almost inception of phones and switching to iPhone is just a pain.1. No guide or help to transfer your critical data(Move to iOS doesnt work at all with high amount of data transfer.If you want to buy, go to brick and motor shop and get your data transfer then and there.2. Over hyped phone, nothing great i have found in the phone. May be i will find it better.3. Total stuck with ecosystem.4. At 90K they don't provide charger and are selling the same as extra. Total cheap strategy to earn more and promote their magsafe.I am not a happy customer till now! In a world where we talk about openness and open for integration, apple gives you a kind of black box... Boo to Apple!\n\n",
#  '\n\n  Superb mobile from Apple.\n\n',
#  '\n\n  The look is retrograde . Feel is cheap. Does not have physical double SIM. The Airtel does not offer eSIM for prepaid connection. Fortunately jio revised an eSIM that got activated in 2hrs’.There is nothing so spectacular about the camera. The cinematic mode is good.This is my first exposure to iphone.Impression : As good as any high  end handset. Android is really more user friendly.Battery life for a new hand set is just good. Sustains 12hrs’ normal mixed use.\n\n',
#  '\n\n  I have purchased my first Iphone every.I can say camera is best in market (Vivo v70 pro+ is biggest competitor), Build quality is good with lots of new feature.if you are iphone 12 user, I will not suggest to you. Because there is no much difference between 12 and 13.But if you are purchasing new iphone or upgrading from 11 or below, then you can recommend this as best option.Iphone competitor samsung is providing foldable phone but they are not worth to buy because foldable are attractive for the first time only, after that you will see the bend clearly.Feedback : This is fully satisfied with cool features\n\n',
#  '\n\n  This is first time iam using an Apple smartphone and iam completely satisfied with this product in Major areas with compare to other android devices and this is the next level experience of using iPhone 13 service device\n\n',
#  '\n\n  After iPhone 4, I am going back to the Apple ecosystem, by purchasing iPhone 13. In the meantime I have used several Android and Windows phones. This is the best, though at a much higher cost. The battery life is a surprise, with a good life of over almost two days, with normal use.\n\n',
#  '\n\n  Pretty Pink Color with amazing features apple has added to the new phone!Feels very light while holding the phone!Happy customer ❤️\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Good one n nice color…go for it camera feature has modified… u can go only u r a apple lover otherwise go for 12\n\n',
#  '\n\n  I am having a great exprience with it after upgrading from my Xr . It feels lighter than my Xr too & find the display really Crisp as earlier i was using an LCD display\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0iPhone is so good but My phone is four times hang so I am facing some difficulties please Solve  problems\n\n',
#  '\n\n  Improved camera.Very Impressive battery.The screen is much brighter.\n\n',
#  '\n\n  I wanted to upgrade from iPhone 7 to latest and I believe I did right in purchasing iPhone 13. Very happy with look and feel , Performance and Battery\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Everything about this phone is best♥️GREAT BATTERY 🔋GREAT CAMERA 📸GREAT DESIGN♥️\n\n',
#  '\n\n  The phone is really good and the response is better than my earlier iphone11. Camera is fab and the cinematic mode really do the magic. However, it is too expensive for the price, which is mainly bcoz of the Apple brand. Also, Apple not providing charger for environment purposes, is fake and I do not agree to it. It is another way of selling accessories at extremely high and bizarre margins.\n\n',
#  '\n\n  If you’re moving from iphone 11 or previous gen then it’s the best iPhone ever. From 12 to 13 , you won’t feel any significant changes. I moved from android to ios and I couldn’t be more happier.\n\n',
#  '\n\n  iPhone 13 looks awesome with great performance and good camera quality totally liked it.\n\n',
#  '\n\n  It’s a great upgrade…camera is good..\n\n',
#  '\n\n  The phone is simply great, however costs much higher than the competition so not at all a value for money in india ,Camera - simply one of the best i have ever used in a phoneOs - buttery smoothBattery - best in class as compared to previous iphonesDisplay- one of the best display , but not a 60hz, you won’t notice the difference untill you get a iphone 13 pro for a whole day, however ios manage 60hz smoothlySecurity - the main reason i choose ios over anyother android, and yes its great and gives a peace of mind that my data is secured with ios.I also now enjoy my ipad more than before due to the eco system apple provided .Overall a great phone but a bit expensive to the functionality it offers , but would recommend iphone12 if you are looking for a great value for money. Not a great difference but that phone cost 30k less than iphone 13 on sales which is way better deal than this one.\n\n',
#  '\n\n  If you are switching from qndroid to iso, then this is a good decision. Excellent battery life and camera. Just go for it.\n\n',
#  '\n\n  Phone, Email & SMS management extremely unfriendly, primitive and restrictiveUnnecessary animation on each actionVery bad user experience\n\n',
#  '\n\n  Best camera, best battery life, fast performance. The size can also be a plus for people who prefer compact phones but still want the best specs.\n\n',
#  '\n\n  Reviewing after 2 months usage.+ve:1. Battery2. Display3. Camera-ve:1. Screen not responding in all the corners, I need to click three or four times2. Portrait mode pictures , one plus does better than this3. Phone got Stuck three times4. When I play PUBG/BGMI fire button takes some time to respond (not sure it’s BGMI issue ) and also with mobile data BGMI not able to handle extreme graphicsNote : these are all my experiences  as new iPhone user who used Oneplus7 earlier.\n\n',
#  "\n\n  you really don't need to upgrade if you bought a new iPhone last year. But anyone with an iPhone 11 or older will find enough new parts and features to consider the new modelsScreenThe screen is notably better than last year's. It's the first iPhone with Apple's ProMotion display, a very high refresh-rate screen technology that was introduced on the iPad Pro in 2017.The screen can adjust to the content on the page to help save battery life and make things feel smoother. If you're just reading a website, for example, it might refresh less frequently and save battery life. But then if you're gaming or scrolling through a long webpage, it'll refresh really fast to make everything much smoother.BatteryBattery life is top-notch and lasts longer than any other iPhone on the market. Unless you're playing games for hours and hoursThat's thanks to a combination of a newer processor, a new screen and a bigger battery. I streamed nine hours of movies, for example, with just over 50% brightness, and still had more than half the battery left.CameraThe regular wide-angle, the zoom and the ultra-wide-angle lenses on the back now allow in more light, which means they're better at taking pictures in the dark.The HDR feature is also better in situations where your subject might have a lot of light behind them, which can normally make people in a picture look dark — all the iPhone 13 phones can keep color and detail even if the sun is right behind someone.You can get really close to an object, like a blueberry or a flower, and capture a lot of detail.\n\n",
#  '\n\n  Scores high on style, looks, great camera, fast. iPhone set-up from previous versions of iPhone is very very fast and smooth. Entire set-up took just 10-15 mins and everything was copied over w/o any loss of data. Face ID set-up is very powerful. Battery life could be still better. Obviously price point could be a little more affordable.\n\n',
#  "\n\n  Apple making fools of images ridden duffers. Overpriced phone, don't have bsic features like 120 hz display, only 3100 mah battery.\n\n",
#  "\n\n  The iPhone 13 is the best iPhone ever. Fantastic phone. The best camera. Fastest processor. And offcourse a status symbol. Go for it. It's the best smart phone.\n\n",
#  '\n\n  Pro: Brighter display, Great cameras, and A15 bionic chipCons: Lacks fast charging.\n\n',
#  '\n\n  Same as iphone 12 expect camara not satisfied go with I phone 12 if you want best camara then I phone 13\n\n',
#  '\n\n  Battery life is a pleasant surprise, and with a 20W chargers it’s a good experience. With the camera enhancements, it’s feels like a good value for Money\n\n',
#  '\n\n  I’m happy with iPhone 13. It’s little bit heavy like iPhone 11 but it’s fine.\n\n',
#  '\n\n  Loved it !\n\n',
#  '\n\n  In one word fantastic…. Beast of a performer..It good right balance of size and performanceBattery life is major USP of this mobile …Two major Cons :-120 htz refresh rate is must have for this price pointCharging Speed is bit slow but that could be managed by great battery life\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0This looks professional colour and perfect👍. Nice product.\n\n',
#  '\n\n  Battery Life is awesome. Since I had issues with my previous iPhone battery i am quite satisfied with this one.\n\n',
#  '\n\n  Go for it guys\n\n',
#  '',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Hi,  I felt bad and stressed by getting a empty box without iphone and power cable\n\n',
#  '\n\n  Nice User Experience\n\n',
#  '\n\n  The midnight colour is little bit like navy blue and besides all the things are good and also I like the new cinematic mode of it.It’s good\n\n',
#  '\n\n  Great to use! Has an amazing camera. Quite light and looks stylish.\n\n',
#  '\n\n  It’s a great phone. After my 6s plus, it’s an amazing upgrade but I wish I would have bought the pro version instead. I miss the features that phone has.\n\n',
#  '\n\n  Its an phone that feels differently in hand as compared to other phones. Absolutely amazing camera quality. The one of the best.\n\n',
#  '\n\n  Good productCamera is superbSmoothness is of next levelFeeling proud and feel honor\n\n',
#  '\n\n  My first iphone\n\n',
#  '\n\n  Good\n\n',
#  '\n\n  Shifted to iOS for the first time. Happy with the purchase. Battery Camera OS everything’s buttery smooth!\n\n',
#  '\n\n  Battery charging very slow  not a good option to buy iPhone 13 face unlock below standard\n\n',
#  "\n\n  took some time to adapt the new interface from android but its all worth it in the end.What's Great?1. Display2. Camera3. Stereo Sound4. Battery5. User InterfaceWhat you will miss?1. Fingerprint scanner2. Jio switch to video call directly from voice call (Facetime !)\n\n",
#  '\n\n  Was using 11 before this. Wanted to go for 13 pro. Wished 120 hertz pro motion display in my phone. But that costed way too much. Nevertheless this standard 13 model is not too behind. Almost same cameras. Amazing battery life and speakers. And build is similar to 12 offourse but functionality is better. Great changes from 12 especially in camera and battery. Perfect value smartphone in 72000₹ (128gb). IOS is IOS. Ecosystem is unmatched. Hence for me a perfect phone.\n\n',
#  '\n\n  I saw in nearby storesIt looks almost like iphone 12 except camera positionBoth the phones are awesomeWhoever is having money can go for itBut people like me can see in stores\n\n',
#  "\n\n  Could've been better, this is just such a small update.. I'd say stick to your old iPhone 12 if you have it.. if not then maybe think of buying this\n\n",
#  '\n\n  Everything almost similar to iPhone 12, either go iphone 12 only or samsung if Android is not an issue. Overrated product. Nothing new.\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Best mobile. Best thing is cinematic video recording and as well as nice picture quality. Update from iphone 11 to 13 and liked it.\n\n',
#  "\n\n  this thing is absolute beast in battery when compared to other iPhone's. I used note 20 ultra before and i am getting nearly the same battery life with this phone in this perfect shape. I am super happy about my purchase. The camera is really great with some new features. if u are looking for a new apple device and your budget is 80k+ u can definitely buy this and not regret.💯\n\n",
#  '\n\n  Just received this in the morning. My mother loves the red colour. Also, the camera’s pretty impressive. Haven’t tested the battery yet. But, I’m sure it’s much better than the previous versions.The best part is that Red colour’s not flashy.\n\n',
#  '\n\n  You have to pay 95000+ for this stupid phone which doesn’t make any sense especially when they don’t even pack a charger and 120hz display in such an expensive phone. Buy Google pixel phone instead.\n\n',
#  '\n\n  This is my first i phone , camera is amazing ,battery is good overall feel is mind blowing , go for it if its your 1st iPhone\n\n',
#  '\n\n  Buy from Dubai not worth 90,000 phone is good ; battery life is amazing and nice true good and nice\n\n',
#  "\n\n  First of all all those chapri who gonna buy it from emi will cry that it is same like iPhone 12 and doesn't have adaptor.Lol then why you bought this😂\n\n",
#  '\n\n  Camera has improved many folds.Battery improvement is like wooooowwww!!!It’s a go go if you own iphone 11 or older.\n\n',
#  '\n\n  The biggest issues starts when u buy iPhone and the phone cries for getting signal for you. If don’t trust buy iPhone and experience it.\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Go and buy this phoneIt has apple bionic 15 chipset which is very powerful.You can play hardcore games like pro players\n\n',
#  '\n\n  Best phone ever . I was using iphone 12 but now I had upgrade to 13 thanks Amazon thank a lot\n\n',
#  '\n\n  Best batteryyy life everr👍🏻👍🏻👍🏻👍🏻Go for it..i m in love with iphone 13Osm phone with osm battery life✌️\n\n',
#  '\n\n\n\n\n                    The media could not be loaded.\n                \n\n\n\n\n  \xa0Beast performance 🔥 battery life is better but problem with this is unable to scan codes apart from that 13 is unbeatable\n\n',
#  "\n\n  This phone sucks buy samsung, buy oppo, buy oneplus, even mi is better than crap apple. Don't but this crap. I regretted it, you will too.\n\n",
#  '',
#  '',
#  '\n\n  SLIGHT speed difference, more batter backup for more than 12 Not worth it Go for 12 instead.. No difference at all\n\n',
#  '',
#  '\n\n  The smartphone marketplace has changed drastically over the span of the past few years. Over the years, it has become more competitive than ever before with a lot of smartphone makers launching their flagship devices every six months. Amid these challenging times Apple, like a bunch of other companies, has maintained a yearly update cycle for its iPhones. In this series, the company, as is customary, announced the iPhone 13 as its successor to last year’s iPhone 12.The newly launched iPhone 13 delivers minor upgrades over the iPhone 12, which includes a smarter camera, a brighter display, a bigger battery and of course, a more advanced processor to name a few. Then there are features like a smaller notch and a less pronounced rear camera module that might seem insignificant compared to the mentioned features but make a world of difference when it comes to usage. Sure, it’s a tad bit heavier than the iPhone 12 but if you compare it with some of the older iPhone models, like the iPhone 11 or the iPhone XR that I have been using, for what seems like aeons now, you will be grateful for everything that the iPhone 13 offers.\n\n',
#  '\n\n  I switched from OnePlus 6T to iPhone 13. Just a fabulous mobile. Amazing camera just like a DSLR in pocket. I purchased my iPhone 13 from iPrime store because of same price online & offline. Bought it at ₹ 81,800.00 (iPhone+ 20w adapter).\n\n',
#  "\n\n  This is the best iPhone till date. Same price. Superb battery and awesome camera. If you're using a iphone 12 dont go for this. If iPhone 10/ 11 blindly purchase it\n\n"]

# %%
txt = pd.DataFrame(ipr)
txt["text"] = txt
txt
# Out:
#                                                     0  \
# 0   \n\n  This product is duplicate of iPhone 12 o...
# 1   \n\n  You should be a bigggggg bot to buy this...
# 2   \n\n  Iphone 13(blue), Outlook looks good but ...
# 3   \n\n  There was a hairline scratch on the scre...
# 4   \n\n  Ignore the negative comments made by ama...
# ..                                                ...
# 81  \n\n  SLIGHT speed difference, more batter bac...
# 82
# 83  \n\n  The smartphone marketplace has changed d...
# 84  \n\n  I switched from OnePlus 6T to iPhone 13....
# 85  \n\n  This is the best iPhone till date. Same ...
#
#                                                  text
# 0   \n\n  This product is duplicate of iPhone 12 o...
# 1   \n\n  You should be a bigggggg bot to buy this...
# 2   \n\n  Iphone 13(blue), Outlook looks good but ...
# 3   \n\n  There was a hairline scratch on the scre...
# 4   \n\n  Ignore the negative comments made by ama...
# ..                                                ...
# 81  \n\n  SLIGHT speed difference, more batter bac...
# 82
# 83  \n\n  The smartphone marketplace has changed d...
# 84  \n\n  I switched from OnePlus 6T to iPhone 13....
# 85  \n\n  This is the best iPhone till date. Same ...
#
# [86 rows x 2 columns]

# %% [markdown]
# **The text as is from the extraction is filled with unwanted texts, stop words, punctuation marks, etc. to clean these off
# we need to define a function to help do the job for us**

# %%
import re # importing Regular Experession "re"
nltk.download('stopwords') # downloading the stopwords
stemmer = nltk.SnowballStemmer("english") # defining the stemmer for the text to be done
from nltk.corpus import stopwords
import string
stopword = set(stopwords.words("english")) # selecting the english stopwords from the list of various languages present

# defining the cleaning the text function for the extracted text
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# Post running the defined function we invoke the same for the text extracted
txt["text"] = txt["text"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bikem\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Joining the cleansed text data into a single paragraph
text = " ".join(i for i in txt.text)
text
# Out:
# "  product duplic iphon  camera design chang low qualiti product buy samsung mobil phone   bigggggg bot buy phoneyou could get iphon  pro that best 😂   iphon  outlook look good attract look dim usag  see fingerprint phone cinemat video featur look great cant use iphon  charg cabl iphon adapt final first iphon experi averag   hairlin scratch screen clear visibl direct tri contact amazon replac ask us connect appl connect appl ask connect amazon blame game begin end pay price awful servic go tag social media amazon appl big scam   ignor negat comment made amateursreason upgrad  camera bigger camera apertur oi cinemat mode low light pictur outstand see  pictur flower taken night also pictur daylight  batteri appl realli done good job batteri manag give good batteri back  processor new  processor better  softwar usual strong point iphon  storag forget you'r get  gig base storag compar  gig last year base model pricewho buy  your alreadi use iphon  dont bother upgrad wait next year  use iphon  previous version sure feel much  price gap iphon   inr offer present iphon   discount hdfc card make actual price around  make sens save  buy year old devic iphon  you'r upgrad iphon  previous  iphon  purchas make sens compar iphon  price get reduc    least alway  display fingerprint   refresh rate  iphon  model india pay lot base model   iphon ’s worth moneyunless ur bjp someth you'r full corrupt money go ahead   phone  😑 ever read review suggest go phone    poor cant afford lmao xdxdxdxdxd money flex buy bore that write review drink coffe chemistri exam  manday cant studi mole concept got bore that came write review read review til good justt wast time go someth product    oneplus  iphon  ui feel iphon give mind blow   money get phone dream get phone definit fulfil one day   i'v use iphon  almost last  year problem ever face entir lifespan batteri life appl final broken apart amaz user experi camera great iphon batteri life iphon  simpli awesom doubt second want upgrad phone jus go   may best one upgrad absolut love phone first time iphon user batteri camera better expect   assum you'r start good foundat think list realli make big differ phone upgrad actual short first thing list improv batteri life second improv camerathi two factor realli matter day day life regular useno thing improv like screen chip performanceoveral soft updat    appl market done quit good job month month keep peopl toe new launch noth great phone android almost incept phone switch iphon  guid help transfer critic datamov io doesnt work high amount data transferif want buy go brick motor shop get data transfer  hype phone noth great found phone may find  total stuck   dont provid charger sell extra total cheap strategi earn promot magsafei happi custom till world talk open open integr appl give kind black box boo appl   superb mobil appl   look retrograd  feel cheap physic doubl sim airtel offer esim prepaid connect fortun jio revis esim got activ there noth spectacular camera cinemat mode goodthi first exposur iphoneimpress  good high  end handset android realli user friendlybatteri life new hand set good sustain ’ normal mix use   purchas first iphon everyi say camera best market vivo  pro biggest competitor build qualiti good lot new featureif iphon  user suggest much differ   purchas new iphon upgrad  recommend best optioniphon competitor samsung provid foldabl phone worth buy foldabl attract first time see bend clearlyfeedback  fulli satisfi cool featur   first time iam use appl smartphon iam complet satisfi product major area compar android devic next level experi use iphon  servic devic   iphon  go back appl ecosystem purchas iphon  meantim use sever android window phone best though much higher cost batteri life surpris good life almost two day normal use   pretti pink color amaz featur appl ad new phonefeel light hold phonehappi custom ❤️                     media could load                  \xa0good one n nice color…go camera featur modified… u go u r appl lov ...

# %%
# using the Vader_lexicon library to run the sentiment analysis on the text extracted and cleansed

nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
txt["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in txt["text"]] # defining the positive polarity for the text
txt["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in txt["text"]] # defining the nagetive polarity for the text
txt["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in txt["text"]] # defining the neutral polarity for the text
txt = txt[["text", "Positive", "Negative", "Neutral"]]
print(txt.head())
# Out:
#                                                 text  Positive  Negative  \
# 0    product duplic iphon  camera design chang lo...     0.000     0.149
# 1    bigggggg bot buy phoneyou could get iphon  p...     0.318     0.000
# 2    iphon  outlook look good attract look dim us...     0.275     0.000
# 3    hairlin scratch screen clear visibl direct t...     0.170     0.232
# 4    ignor negat comment made amateursreason upgr...     0.139     0.038
#
#    Neutral
# 0    0.851
# 1    0.682
# 2    0.725
# 3    0.597
# 4    0.823
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bikem\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
x = sum(txt["Positive"])
y = sum(txt["Negative"])
z = sum(txt["Neutral"])

def sentiment_score(a, b, c):
    if (a>b) and (a>c):
        print("Positive 😊 ")
    elif (b>a) and (b>c):
        print("Negative 😠 ")
    else:
        print("Neutral 🙂 ")
sentiment_score(x, y, z)
# Out:
# Neutral 🙂

# %%
# printing the sentiment scores for the text
print("Positive: ", x)
print("Negative: ", y)
print("Neutral: ", z)
# Out:
# Positive:  22.409000000000002
# Negative:  3.290000000000001
# Neutral:  56.30199999999999

# %%
ip_rev_string = " ".join(txt["text"])

# %%
ip_rev_string
# Out:
# "  product duplic iphon  camera design chang low qualiti product buy samsung mobil phone   bigggggg bot buy phoneyou could get iphon  pro that best 😂   iphon  outlook look good attract look dim usag  see fingerprint phone cinemat video featur look great cant use iphon  charg cabl iphon adapt final first iphon experi averag   hairlin scratch screen clear visibl direct tri contact amazon replac ask us connect appl connect appl ask connect amazon blame game begin end pay price awful servic go tag social media amazon appl big scam   ignor negat comment made amateursreason upgrad  camera bigger camera apertur oi cinemat mode low light pictur outstand see  pictur flower taken night also pictur daylight  batteri appl realli done good job batteri manag give good batteri back  processor new  processor better  softwar usual strong point iphon  storag forget you'r get  gig base storag compar  gig last year base model pricewho buy  your alreadi use iphon  dont bother upgrad wait next year  use iphon  previous version sure feel much  price gap iphon   inr offer present iphon   discount hdfc card make actual price around  make sens save  buy year old devic iphon  you'r upgrad iphon  previous  iphon  purchas make sens compar iphon  price get reduc    least alway  display fingerprint   refresh rate  iphon  model india pay lot base model   iphon ’s worth moneyunless ur bjp someth you'r full corrupt money go ahead   phone  😑 ever read review suggest go phone    poor cant afford lmao xdxdxdxdxd money flex buy bore that write review drink coffe chemistri exam  manday cant studi mole concept got bore that came write review read review til good justt wast time go someth product    oneplus  iphon  ui feel iphon give mind blow   money get phone dream get phone definit fulfil one day   i'v use iphon  almost last  year problem ever face entir lifespan batteri life appl final broken apart amaz user experi camera great iphon batteri life iphon  simpli awesom doubt second want upgrad phone jus go   may best one upgrad absolut love phone first time iphon user batteri camera better expect   assum you'r start good foundat think list realli make big differ phone upgrad actual short first thing list improv batteri life second improv camerathi two factor realli matter day day life regular useno thing improv like screen chip performanceoveral soft updat    appl market done quit good job month month keep peopl toe new launch noth great phone android almost incept phone switch iphon  guid help transfer critic datamov io doesnt work high amount data transferif want buy go brick motor shop get data transfer  hype phone noth great found phone may find  total stuck   dont provid charger sell extra total cheap strategi earn promot magsafei happi custom till world talk open open integr appl give kind black box boo appl   superb mobil appl   look retrograd  feel cheap physic doubl sim airtel offer esim prepaid connect fortun jio revis esim got activ there noth spectacular camera cinemat mode goodthi first exposur iphoneimpress  good high  end handset android realli user friendlybatteri life new hand set good sustain ’ normal mix use   purchas first iphon everyi say camera best market vivo  pro biggest competitor build qualiti good lot new featureif iphon  user suggest much differ   purchas new iphon upgrad  recommend best optioniphon competitor samsung provid foldabl phone worth buy foldabl attract first time see bend clearlyfeedback  fulli satisfi cool featur   first time iam use appl smartphon iam complet satisfi product major area compar android devic next level experi use iphon  servic devic   iphon  go back appl ecosystem purchas iphon  meantim use sever android window phone best though much higher cost batteri life surpris good life almost two day normal use   pretti pink color amaz featur appl ad new phonefeel light hold phonehappi custom ❤️                     media could load                  \xa0good one n nice color…go camera featur modified… u go u r appl lov ...

# %%
# Creating a wordcloud of the text extracted
wordcloud_ip = WordCloud(background_color='White',
                      width=1800,
                      height=1400
                     ).generate(ip_rev_string)

plt.imshow(wordcloud_ip)

# %% [markdown]
# **We notice that the words after processing are a bit senseless as they are not stemmed properly. We can also use the extracted text in an alternate way. To help understand let's tryout**

# %%
# defining the cleaning the text function for the extracted text
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub("[^A-Za-z" "]+"," ", text)
    text = re.sub("[0-9" "]+"," ", text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text

# Post running the defined function we invoke the same for the text extracted
txt["text"] = txt["text"].apply(clean)

# %%
ip_rev_string = " ".join(ipr)

import nltk
# from nltk.corpus import stopwords


# Removing unwanted symbols incase if exists
ip_rev_string = re.sub("[^A-Za-z" "]+"," ", ip_rev_string).lower()
ip_rev_string = re.sub("[0-9" "]+"," ", ip_rev_string)

# words that contained in iphone XR reviews
ip_reviews_words = ip_rev_string.split(" ")
ip_reviews_words
# Out:
# ['',
#  'this',
#  'product',
#  'is',
#  'duplicate',
#  'of',
#  'iphone',
#  'only',
#  'camera',
#  'design',
#  'changed',
#  'very',
#  'low',
#  'quality',
#  'of',
#  'this',
#  'product',
#  'buy',
#  'samsung',
#  'mobile',
#  'phone',
#  'you',
#  'should',
#  'be',
#  'a',
#  'bigggggg',
#  'bot',
#  'to',
#  'buy',
#  'this',
#  'phoneyou',
#  'could',
#  'get',
#  'iphone',
#  'pro',
#  'that',
#  's',
#  'the',
#  'best',
#  'iphone',
#  'blue',
#  'outlook',
#  'looks',
#  'good',
#  'but',
#  'not',
#  'attractive',
#  'looks',
#  'dim',
#  'after',
#  'usage',
#  'of',
#  'min',
#  'i',
#  'can',
#  'see',
#  'fingerprints',
#  'all',
#  'over',
#  'the',
#  'phone',
#  'cinematic',
#  'video',
#  'features',
#  'looks',
#  'great',
#  'can',
#  't',
#  'use',
#  'iphone',
#  'charging',
#  'cable',
#  'with',
#  'other',
#  'iphone',
#  'adapters',
#  'finally',
#  'my',
#  'first',
#  'iphone',
#  'experience',
#  'is',
#  'average',
#  'there',
#  'was',
#  'a',
#  'hairline',
#  'scratch',
#  'on',
#  'the',
#  'screen',
#  'which',
#  'is',
#  'not',
#  'clearly',
#  'visible',
#  'directly',
#  'when',
#  'we',
#  'tried',
#  'contacting',
#  'amazon',
#  'for',
#  'the',
#  'replacement',
#  'they',
#  'asked',
#  'us',
#  'to',
#  'connect',
#  'to',
#  'apple',
#  'and',
#  'when',
#  'connected',
#  'to',
#  'apple',
#  'they',
#  'asked',
#  'to',
#  'connect',
#  'with',
#  'amazon',
#  'blame',
#  'game',
#  'begins',
#  'and',
#  'we',
#  'end',
#  'up',
#  'paying',
#  'the',
#  'price',
#  'awfull',
#  'service',
#  'i',
#  'am',
#  'going',
#  'to',
#  'tag',
#  'on',
#  'the',
#  'social',
#  'media',
#  'both',
#  'amazon',
#  'and',
#  'apple',
#  'such',
#  'a',
#  'big',
#  'scam',
#  'ignore',
#  'the',
#  'negative',
#  'comments',
#  'made',
#  'by',
#  'amateurs',
#  'reasons',
#  'for',
#  'upgrade',
#  'camera',
#  'bigger',
#  'camera',
#  'aperture',
#  'ois',
#  'cinematic',
#  'mode',
#  'low',
#  'light',
#  'pictures',
#  'are',
#  'outstanding',
#  'as',
#  'you',
#  'can',
#  'see',
#  'the',
#  'nd',
#  'picture',
#  'of',
#  'the',
#  'flower',
#  'taken',
#  'at',
#  'night',
#  'also',
#  'some',
#  'of',
#  'the',
#  'pictures',
#  'during',
#  'daylight',
#  'for',
#  'reference',
#  'battery',
#  'apple',
#  'has',
#  'really',
#  'done',
#  'a',
#  'good',
#  'job',
#  'in',
#  'battery',
#  'management',
#  'it',
#  's',
#  'giving',
#  'a',
#  'good',
#  'battery',
#  'back',
#  'up',
#  'processor',
#  'new',
#  'a',
#  'processor',
#  'and',
#  'better',
#  'performance',
#  'software',
#  'this',
#  'is',
#  'the',
#  'usual',
#  'strong',
#  'point',
#  'of',
#  'any',
#  'iphone',
#  'with',
#  'ios',
#  'storage',
#  'not',
#  'to',
#  'forget',
#  'you',
#  're',
#  'now',
#  'getting',
#  'gigs',
#  'as',
#  'base',
#  'storage',
#  'compared',
#  'to',
#  'gigs',
#  'last',
#  'year',
#  'on',
#  'base',
#  'model',
#  'price',
#  'who',
#  'should',
#  'buy',
#  'this',
#  'phone',
#  'if',
#  'you',
#  're',
#  'already',
#  'using',
#  'an',
#  'iphone',
#  'don',
#  't',
#  'bother',
#  'to',
#  'upgrade',
#  'wait',
#  'for',
#  'next',
#  'year',
#  'release',
#  'those',
#  'who',
#  'are',
#  'using',
#  'iphone',
#  'or',
#  'previous',
#  'versions',
#  'can',
#  'surely',
#  'feel',
#  'much',
#  'of',
#  'a',
#  'difference',
#  'price',
#  'gap',
#  'iphone',
#  'is',
#  'inr',
#  'with',
#  'no',
#  'offers',
#  'at',
#  'present',
#  'iphone',
#  'with',
#  'discount',
#  'on',
#  'hdfc',
#  'cards',
#  'makes',
#  'the',
#  'actual',
#  'price',
#  'around',
#  'it',
#  'makes',
#  'no',
#  'sense',
#  'to',
#  'save',
#  'and',
#  'buy',
#  'an',
#  'year',
#  'old',
#  'device',
#  'iphone',
#  'if',
#  'you',
#  're',
#  'upgrading',
#  'from',
#  'iphone',
#  'or',
#  'previous',
#  'versions',
#  'iphone',
#  'purchase',
#  'will',
#  'only',
#  'make',
#  'sense',
#  'compared',
#  'to',
#  'iphone',
#  'if',
#  'it',
#  's',
#  'price',
#  'gets',
#  'reduced',
#  'to',
#  'customer',
#  'expectations',
#  'at',
#  'least',
#  'an',
#  'always',
#  'on',
#  'display',
#  'on',
#  'display',
#  'fingerprint',
#  'scanner',
#  'a',
#  'hz',
#  'refresh',
#  'rate',
#  'if',
#  'not',
#  'hz',
#  'for',
#  'iphone',
#  'model',
#  'in',
#  'india',
#  'we',
#  'are',
#  'paying',
#  'a',
#  'lot',
#  'for',
#  'base',
#  'models',
#  'just',
#  'but',
#  'iphone',
#  'it',
#  's',
#  'not',
#  'worth',
#  'the',
#  'money',
#  'unless',
#  'ur',
#  'from',
#  'bjp',
#  'or',
#  'something',
#  'where',
#  'you',
#  're',
#  'full',
#  'with',
#  'corrupt',
#  'money',
#  'then',
#  'go',
#  'ahead',
#  'same',
#  'as',
#  'i',
#  'phone',
#  'who',
#  'so',
#  'ever',
#  'is',
#  'reading',
#  'this',
#  'review',
#  'i',
#  'suggest',
#  'go',
#  'for',
#  'i',
#  'phone',
#  'i',
#  'am',
#  'poor',
#  'and',
#  'i',
#  'cant',
#  'afford',
#  'it',
#  'lmao',
#  'xdxdxdxdxd',
#  'so',
#  'if',
#  'you',
#  'have',
#  'money',
#  'to',
#  'flex',
#  'buy',
#  'it',
#  'i',
#  'am',
#  'bored',
#  'thats',
#  'why',
#  'i',
#  'am',
#  'writing',
#  'this',
#  'review',
#  'while',
#  'drinking',
#  'coffee',
#  'i',
#  'have',
#  'my',
#  'chemistry',
#  'exam',
#  'on',
#  'manday',
#  'and',
#  'cant',
#  'study',
#  'mole',
#  'concept',
#  'and',
#  'got',
#  'bored',
#  'thats',
#  'why',
#  'i',
#  'came',
#  'here',
#  'to',
#  'write',
#  'this',
#  'review',
#  'if',
#  'you',
#  'read',
#  'this',
#  'review',
#  'til',
#  'here',
#  'very',
#  'good',
#  'you',
#  'justt',
#  'wasted',
#  'your',
#  'time',
#  'now',
#  'go',
#  'and',
#  'do',
#  'something',
#  'productive',
#  'oneplus',
#  'to',
#  'iphone',
#  'the',
#  'ui',
#  'and',
#  'feel',
#  'which',
#  'iphone',
#  'gives',
#  'is',
#  'mind',
#  'blowing',
#  'i',
#  'do',
#  'not',
#  'have',
#  'money',
#  'that',
#  'i',
#  'can',
#  'get',
#  'a',
#  'phone',
#  'but',
#  'i',
#  'have',
#  'a',
#  'dream',
#  'to',
#  'get',
#  'a',
#  'phone',
#  'which',
#  'will',
#  'definitely',
#  'be',
#  'fulfilled',
#  'one',
#  'day',
#  'i',
#  've',
#  'been',
#  'using',
#  'iphone',
#  's',
#  'for',
#  'almost',
#  'last',
#  'years',
#  'the',
#  'only',
#  'problem',
#  'i',
#  'ever',
#  'faced',
#  'in',
#  'its',
#  'entire',
#  'lifespan',
#  'was',
#  'the',
#  'battery',
#  'life',
#  'and',
#  'apple',
#  'has',
#  'finally',
#  'broken',
#  'that',
#  'apart',
#  'from',
#  'amazing',
#  'user',
#  'experience',
#  'camera',
#  'and',
#  'all',
#  'that',
#  'is',
#  'great',
#  'about',
#  'iphone',
#  'the',
#  'battery',
#  'life',
#  'of',
#  'iphone',
#  'is',
#  'simply',
#  'awesome',
#  'do',
#  'not',
#  'doubt',
#  'for',
#  'a',
#  'second',
#  'if',
#  'you',
#  'want',
#  'to',
#  'upgrade',
#  'your',
#  'phone',
#  'jus',
#  'go',
#  'for',
#  'it',
#  'may',
#  'not',
#  'be',
#  'the',
#  'best',
#  'one',
#  'to',
#  'upgrade',
#  'to',
#  'but',
#  'i',
#  'absolutely',
#  'loved',
#  'this',
#  'phone',
#  'as',
#  'a',
#  'first',
#  'time',
#  'iphone',
#  'user',
#  'battery',
#  'and',
#  'camera',
#  'are',
#  'better',
#  'than',
#  'expected',
#  'assuming',
#  'you',
#  're',
#  'starting',
#  'with',
#  'a',
#  'good',
#  'foundation',
#  'i',
#  'think',
#  'the',
#  'list',
#  'of',
#  'what',
#  'really',
#  'makes',
#  'a',
#  'big',
#  'difference',
#  'in',
#  'phone',
#  'upgrades',
#  'is',
#  'actually',
#  'short',
#  'the',
#  'first',
#  'thing',
#  'on',
#  'the',
#  'list',
#  'is',
#  'improved',
#  'battery',
#  'life',
#  'the',
#  'second',
#  'is',
#  'an',
#  'improved',
#  'camera',
#  'this',
#  'two',
#  'factor',
#  'really',
#  'matter',
#  'in',
#  'our',
#  'day',
#  'to',
#  'day',
#  'life',
#  'and',
#  'regular',
#  'useno',
#  'any',
#  'other',
#  'things',
#  'are',
#  'improved',
#  'like',
#  'a',
#  'screen',
#  'and',
#  'chip',
#  'performanceoverall',
#  'soft',
#  'update',
#  'for',
#  'apple',
#  'marketing',
#  'has',
#  'done',
#  'quite',
#  'a',
#  'good',
#  'job',
#  'month',
#  'after',
#  'month',
#  'to',
#  'keep',
#  'people',
#  'on',
#  'their',
#  'toes',
#  'with',
#  'their',
#  'new',
#  'launches',
#  'where',
#  'there',
#  'is',
#  'nothing',
#  'great',
#  'about',
#  'this',
#  'phone',
#  'i',
#  'have',
#  'been',
#  'on',
#  'android',
#  'for',
#  'almost',
#  'inception',
#  'of',
#  'phones',
#  'and',
#  'switching',
#  'to',
#  'iphone',
#  'is',
#  'just',
#  'a',
#  'pain',
#  'no',
#  'guide',
#  'or',
#  'help',
#  'to',
#  'transfer',
#  'your',
#  'critical',
#  'data',
#  'move',
#  'to',
#  'ios',
#  'doesnt',
#  'work',
#  'at',
#  'all',
#  'with',
#  'high',
#  'amount',
#  'of',
#  'data',
#  'transfer',
#  'if',
#  'you',
#  'want',
#  'to',
#  'buy',
#  'go',
#  'to',
#  'brick',
#  'and',
#  'motor',
#  'shop',
#  'and',
#  'get',
#  'your',
#  'data',
#  'transfer',
#  'then',
#  'and',
#  'there',
#  'over',
#  'hyped',
#  'phone',
#  'nothing',
#  'great',
#  'i',
#  'have',
#  'found',
#  'in',
#  'the',
#  'phone',
#  'may',
#  'be',
#  'i',
#  'will',
#  'find',
#  'it',
#  'better',
#  'total',
#  'stuck',
#  'with',
#  'ecosystem',
#  'at',
#  'k',
#  'they',
#  'don',
#  't',
#  'provide',
#  'charger',
#  'and',
#  'are',
#  'selling',
#  'the',
#  'same',
#  'as',
#  'extra',
#  'total',
#  'cheap',
#  'strategy',
#  'to',
#  'earn',
#  'more',
#  'and',
#  'promote',
#  'their',
#  'magsafe',
#  'i',
#  'am',
#  'not',
#  'a',
#  'happy',
#  'customer',
#  'till',
#  'now',
#  'in',
#  'a',
#  'world',
#  'where',
#  'we',
#  'talk',
#  'about',
#  'openness',
#  'and',
#  'open',
#  'for',
#  'integration',
#  'apple',
#  'gives',
#  'you',
#  'a',
#  'kind',
#  'of',
#  'black',
#  'box',
#  'boo',
#  'to',
#  'apple',
#  'superb',
#  'mobile',
#  'from',
#  'apple',
#  'the',
#  'look',
#  'is',
#  'retrograde',
#  'feel',
#  'is',
#  'cheap',
#  'does',
#  'not',
#  'have',
#  'physical',
#  'double',
#  'sim',
#  'the',
#  'airtel',
#  'does',
#  'not',
#  'offer',
#  'esim',
#  'for',
#  'prepaid',
#  'connection',
#  'fortunately',
#  'jio',
#  'revised',
#  'an',
#  'esim',
#  'that',
#  'got',
#  'activated',
#  'in',
#  'hrs',
#  'there',
#  'is',
#  'nothing',
#  'so',
#  'spectacular',
#  'about',
#  'the',
#  'camera',
#  'the',
#  'cinematic',
#  'mode',
#  'is',
#  'good',
#  'this',
#  'is',
#  'my',
#  'first',
#  'exposure',
#  'to',
#  'iphone',
#  'impression',
#  'as',
#  'good',
#  'as',
#  'any',
#  'high',
#  'end',
#  'handset',
#  'android',
#  'is',
#  'really',
#  'more',
#  'user',
#  'friendly',
#  'battery',
#  'life',
#  'for',
#  'a',
#  'new',
#  'hand',
#  'set',
#  'is',
#  'just',
#  'good',
#  'sustains',
#  'hrs',
#  'normal',
#  'mixed',
#  'use',
#  'i',
#  'have',
#  'purchased',
#  'my',
#  'first',
#  'iphone',
#  'every',
#  'i',
#  'can',
#  'say',
#  'camera',
#  'is',
#  'best',
#  'in',
#  'market',
#  'vivo',
#  'v',
#  'pro',
#  'is',
#  'biggest',
#  'competitor',
#  'build',
#  'quality',
#  'is',
#  'good',
#  'with',
#  'lots',
#  'of',
#  'new',
#  'feature',
#  'if',
#  'you',
#  'are',
#  'iphone',
#  'user',
#  'i',
#  'will',
#  'not',
#  'suggest',
#  'to',
#  'you',
#  'because',
#  'there',
#  'is',
#  ...]

# %%
#TFIDF
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ip_reviews_words, use_idf=True,ngram_range=(1, 3))
X = vectorizer.fit_transform(ip_reviews_words)

with open("stop.txt","r") as sw:
    stop_words = sw.read()
    
stop_words = stop_words.split("\n")

stop_words.extend(["mobile","time","android","phone","device","screen","battery","product","good","day","price"])

ip_reviews_words = [w for w in ip_reviews_words if not w in stop_words]

# Joinining all the reviews into single paragraph 
ip_rev_string = " ".join(ip_reviews_words)
ip_rev_string
# Out:
# C:\Users\bikem\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass input=['', 'this', 'product', 'is', 'duplicate', 'of', 'iphone', 'only', 'camera', 'design', 'changed', 'very', 'low', 'quality', 'of', 'this', 'product', 'buy', 'samsung', 'mobile', 'phone', 'you', 'should', 'be', 'a', 'bigggggg', 'bot', 'to', 'buy', 'this', 'phoneyou', 'could', 'get', 'iphone', 'pro', 'that', 's', 'the', 'best', 'iphone', 'blue', 'outlook', 'looks', 'good', 'but', 'not', 'attractive', 'looks', 'dim', 'after', 'usage', 'of', 'min', 'i', 'can', 'see', 'fingerprints', 'all', 'over', 'the', 'phone', 'cinematic', 'video', 'features', 'looks', 'great', 'can', 't', 'use', 'iphone', 'charging', 'cable', 'with', 'other', 'iphone', 'adapters', 'finally', 'my', 'first', 'iphone', 'experience', 'is', 'average', 'there', 'was', 'a', 'hairline', 'scratch', 'on', 'the', 'screen', 'which', 'is', 'not', 'clearly', 'visible', 'directly', 'when', 'we', 'tried', 'contacting', 'amazon', 'for', 'the', 'replacement', 'they', 'asked', 'us', 'to', 'connect', 'to', 'apple', 'and', 'when', 'connected', 'to', 'apple', 'they', 'asked', 'to', 'connect', 'with', 'amazon', 'blame', 'game', 'begins', 'and', 'we', 'end', 'up', 'paying', 'the', 'price', 'awfull', 'service', 'i', 'am', 'going', 'to', 'tag', 'on', 'the', 'social', 'media', 'both', 'amazon', 'and', 'apple', 'such', 'a', 'big', 'scam', 'ignore', 'the', 'negative', 'comments', 'made', 'by', 'amateurs', 'reasons', 'for', 'upgrade', 'camera', 'bigger', 'camera', 'aperture', 'ois', 'cinematic', 'mode', 'low', 'light', 'pictures', 'are', 'outstanding', 'as', 'you', 'can', 'see', 'the', 'nd', 'picture', 'of', 'the', 'flower', 'taken', 'at', 'night', 'also', 'some', 'of', 'the', 'pictures', 'during', 'daylight', 'for', 'reference', 'battery', 'apple', 'has', 'really', 'done', 'a', 'good', 'job', 'in', 'battery', 'management', 'it', 's', 'giving', 'a', 'good', 'battery', 'back', 'up', 'processor', 'new', 'a', 'processor', 'and', 'better', 'performance', 'software', 'this', 'is', 'the', 'usual', 'strong', 'point', 'of', 'any', 'iphone', 'with', 'ios', 'storage', 'not', 'to', 'forget', 'you', 're', 'now', 'getting', 'gigs', 'as', 'base', 'storage', 'compared', 'to', 'gigs', 'last', 'year', 'on', 'base', 'model', 'price', 'who', 'should', 'buy', 'this', 'phone', 'if', 'you', 're', 'already', 'using', 'an', 'iphone', 'don', 't', 'bother', 'to', 'upgrade', 'wait', 'for', 'next', 'year', 'release', 'those', 'who', 'are', 'using', 'iphone', 'or', 'previous', 'versions', 'can', 'surely', 'feel', 'much', 'of', 'a', 'difference', 'price', 'gap', 'iphone', 'is', 'inr', 'with', 'no', 'offers', 'at', 'present', 'iphone', 'with', 'discount', 'on', 'hdfc', 'cards', 'makes', 'the', 'actual', 'price', 'around', 'it', 'makes', 'no', 'sense', 'to', 'save', 'and', 'buy', 'an', 'year', 'old', 'device', 'iphone', 'if', 'you', 're', 'upgrading', 'from', 'iphone', 'or', 'previous', 'versions', 'iphone', 'purchase', 'will', 'only', 'make', 'sense', 'compared', 'to', 'iphone', 'if', 'it', 's', 'price', 'gets', 'reduced', 'to', 'customer', 'expectations', 'at', 'least', 'an', 'always', 'on', 'display', 'on', 'display', 'fingerprint', 'scanner', 'a', 'hz', 'refresh', 'rate', 'if', 'not', 'hz', 'for', 'iphone', 'model', 'in', 'india', 'we', 'are', 'paying', 'a', 'lot', 'for', 'base', 'models', 'just', 'but', 'iphone', 'it', 's', 'not', 'worth', 'the', 'money', 'unless', 'ur', 'from', 'bjp', 'or', 'something', 'where', 'you', 're', 'full', 'with', 'corrupt', 'money', 'then', 'go', 'ahead', 'same', 'as', 'i', 'phone', 'who', 'so', 'ever', 'is', 'reading', 'this', 'review', 'i', 'suggest', 'go', 'for', 'i', 'phone', 'i', 'am', 'poor', 'and', 'i', 'cant', 'afford', 'it', 'lmao', 'xdxdxdxdxd', 'so', 'if', 'you', 'have', 'money', 'to', 'flex', 'buy', 'it', 'i', 'am', 'bored', 'thats', 'why', 'i', 'am', 'writing', 'this', 'review', 'while', 'drinking', 'coffee', 'i', 'have', 'my', 'chemistry', 'exam', 'on', 'manday', 'and', 'cant ...
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# ' duplicate iphone camera design changed low quality buy samsung bigggggg bot buy phoneyou iphone pro iphone blue outlook attractive dim usage min fingerprints cinematic video features great iphone charging cable iphone adapters finally iphone experience average hairline scratch visible directly contacting amazon replacement asked connect apple connected apple asked connect amazon blame game begins end paying awfull service tag social media amazon apple big scam ignore negative comments made amateurs reasons upgrade camera bigger camera aperture ois cinematic mode low light pictures outstanding picture flower night pictures daylight reference apple job management giving back processor processor performance software usual strong point iphone ios storage forget gigs base storage compared gigs year base model buy iphone don bother upgrade wait year release iphone previous versions surely feel difference gap iphone inr offers present iphone discount hdfc cards makes actual makes sense save buy year iphone upgrading iphone previous versions iphone purchase make sense compared iphone reduced customer expectations display display fingerprint scanner hz refresh rate hz iphone model india paying lot base models iphone worth money ur bjp full corrupt money ahead reading review suggest poor afford lmao xdxdxdxdxd money flex buy bored writing review drinking coffee chemistry exam manday study mole concept bored write review read review til justt wasted productive oneplus iphone ui feel iphone mind blowing money dream fulfilled ve iphone years problem faced entire lifespan life apple finally broken amazing user experience camera great iphone life iphone simply awesome doubt upgrade jus upgrade absolutely loved iphone user camera expected assuming starting foundation list makes big difference upgrades short thing list improved life improved camera factor matter life regular useno things improved chip performanceoverall soft update apple marketing job month month people toes launches great inception phones switching iphone pain guide transfer critical data move ios doesnt work high amount data transfer buy brick motor shop data transfer hyped great found find total stuck ecosystem don provide charger selling extra total cheap strategy earn promote magsafe happy customer till world talk openness open integration apple kind black box boo apple superb apple retrograde feel cheap physical double sim airtel offer esim prepaid connection fortunately jio revised esim activated hrs spectacular camera cinematic mode exposure iphone impression high end handset user friendly life hand set sustains hrs normal mixed purchased iphone camera market vivo pro biggest competitor build quality lots feature iphone user suggest difference purchasing iphone upgrading recommend option iphone competitor samsung providing foldable worth buy foldable attractive bend feedback fully satisfied cool features iam apple smartphone iam completely satisfied major areas compare devices level experience iphone service iphone back apple ecosystem purchasing iphone meantime windows phones higher cost life surprise life days normal pretty pink color amazing features apple added feels light holding happy customer media loaded nice color camera feature modified apple lover great exprience upgrading xr feels lighter xr find display crisp earlier lcd display media loaded iphone times hang facing difficulties solve problems improved camera impressive brighter wanted upgrade iphone latest purchasing iphone happy feel performance media loaded great great camera great design response earlier iphone camera fab cinematic mode magic expensive bcoz apple brand apple providing charger environment purposes fake agree selling accessories extremely high bizarre margins moving iphone previous gen iphone won feel significant moved ios couldn happier iphone awesome great performance camera quality totally great upgrade camera simply great costs higher competition money india camera simply phoneos b ...

# %%
# Corpus level word cloud

wordcloud_ip = WordCloud(
                      background_color='White',
                      width=1800,
                      height=1400
                     ).generate(ip_rev_string)

plt.imshow(wordcloud_ip)

# %%
# positive words # Choose the path for +ve words stored in system
with open("positive-words.txt","r") as pos:
  poswords = pos.read().split("\n")

# Positive word cloud
# Choosing the only words which are present in positive words
ip_pos_in_pos = " ".join ([w for w in ip_reviews_words if w in poswords])

wordcloud_pos_in_pos = WordCloud(
                      background_color='White',
                      width=1800,
                      height=1400
                     ).generate(ip_pos_in_pos)
plt.figure(2)
plt.imshow(wordcloud_pos_in_pos)

# %%
with open("negative-words.txt", "r") as neg:
  negwords = neg.read().split("\n")

# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join ([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(ip_neg_in_neg)
plt.figure(3)
plt.imshow(wordcloud_neg_in_neg)

# %% [markdown]
# **We can also try and see bigrams and the wordclouds using them, additionally check the bigram frequency as well**

# %%
# we first cleanse the data again in a new manner
nltk.download('punkt')

WNL = nltk.WordNetLemmatizer()

# Lowercase and tokenize
text = ip_rev_string.lower()

# Remove single quote early since it causes problems with the tokenizer.
text = text.replace("'", "")

tokens = nltk.word_tokenize(text)
text1 = nltk.Text(tokens)

# Remove extra chars and remove stop words.
text_content = [''.join(re.split("[ .,;:!?‘’``''@#$%^_&*()<>{}~\n\t\\\-]", word)) for word in text1]

# Create a set of stopwords
stopwords_wc = set(STOPWORDS)
customised_words = ['price', 'great'] # If you want to remove any particular word form text which does not contribute much in meaning

new_stopwords = stopwords_wc.union(customised_words)

# Remove stop words
text_content = [word for word in text_content if word not in new_stopwords]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bikem\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Take only non-empty entries
text_content = [s for s in text_content if len(s) != 0]

# Best to get the lemmas of each word to reduce the number of similar words
text_content = [WNL.lemmatize(t) for t in text_content]

nltk_tokens = nltk.word_tokenize(text)  
bigrams_list = list(nltk.bigrams(text_content))
print(bigrams_list)

dictionary2 = [' '.join(tup) for tup in bigrams_list]
print (dictionary2)
# Out:
# [('duplicate', 'iphone'), ('iphone', 'camera'), ('camera', 'design'), ('design', 'changed'), ('changed', 'low'), ('low', 'quality'), ('quality', 'buy'), ('buy', 'samsung'), ('samsung', 'bigggggg'), ('bigggggg', 'bot'), ('bot', 'buy'), ('buy', 'phoneyou'), ('phoneyou', 'iphone'), ('iphone', 'pro'), ('pro', 'iphone'), ('iphone', 'blue'), ('blue', 'outlook'), ('outlook', 'attractive'), ('attractive', 'dim'), ('dim', 'usage'), ('usage', 'min'), ('min', 'fingerprint'), ('fingerprint', 'cinematic'), ('cinematic', 'video'), ('video', 'feature'), ('feature', 'iphone'), ('iphone', 'charging'), ('charging', 'cable'), ('cable', 'iphone'), ('iphone', 'adapter'), ('adapter', 'finally'), ('finally', 'iphone'), ('iphone', 'experience'), ('experience', 'average'), ('average', 'hairline'), ('hairline', 'scratch'), ('scratch', 'visible'), ('visible', 'directly'), ('directly', 'contacting'), ('contacting', 'amazon'), ('amazon', 'replacement'), ('replacement', 'asked'), ('asked', 'connect'), ('connect', 'apple'), ('apple', 'connected'), ('connected', 'apple'), ('apple', 'asked'), ('asked', 'connect'), ('connect', 'amazon'), ('amazon', 'blame'), ('blame', 'game'), ('game', 'begin'), ('begin', 'end'), ('end', 'paying'), ('paying', 'awfull'), ('awfull', 'service'), ('service', 'tag'), ('tag', 'social'), ('social', 'medium'), ('medium', 'amazon'), ('amazon', 'apple'), ('apple', 'big'), ('big', 'scam'), ('scam', 'ignore'), ('ignore', 'negative'), ('negative', 'comment'), ('comment', 'made'), ('made', 'amateur'), ('amateur', 'reason'), ('reason', 'upgrade'), ('upgrade', 'camera'), ('camera', 'bigger'), ('bigger', 'camera'), ('camera', 'aperture'), ('aperture', 'ois'), ('ois', 'cinematic'), ('cinematic', 'mode'), ('mode', 'low'), ('low', 'light'), ('light', 'picture'), ('picture', 'outstanding'), ('outstanding', 'picture'), ('picture', 'flower'), ('flower', 'night'), ('night', 'picture'), ('picture', 'daylight'), ('daylight', 'reference'), ('reference', 'apple'), ('apple', 'job'), ('job', 'management'), ('management', 'giving'), ('giving', 'back'), ('back', 'processor'), ('processor', 'processor'), ('processor', 'performance'), ('performance', 'software'), ('software', 'usual'), ('usual', 'strong'), ('strong', 'point'), ('point', 'iphone'), ('iphone', 'io'), ('io', 'storage'), ('storage', 'forget'), ('forget', 'gig'), ('gig', 'base'), ('base', 'storage'), ('storage', 'compared'), ('compared', 'gig'), ('gig', 'year'), ('year', 'base'), ('base', 'model'), ('model', 'buy'), ('buy', 'iphone'), ('iphone', 'don'), ('don', 'bother'), ('bother', 'upgrade'), ('upgrade', 'wait'), ('wait', 'year'), ('year', 'release'), ('release', 'iphone'), ('iphone', 'previous'), ('previous', 'version'), ('version', 'surely'), ('surely', 'feel'), ('feel', 'difference'), ('difference', 'gap'), ('gap', 'iphone'), ('iphone', 'inr'), ('inr', 'offer'), ('offer', 'present'), ('present', 'iphone'), ('iphone', 'discount'), ('discount', 'hdfc'), ('hdfc', 'card'), ('card', 'make'), ('make', 'actual'), ('actual', 'make'), ('make', 'sense'), ('sense', 'save'), ('save', 'buy'), ('buy', 'year'), ('year', 'iphone'), ('iphone', 'upgrading'), ('upgrading', 'iphone'), ('iphone', 'previous'), ('previous', 'version'), ('version', 'iphone'), ('iphone', 'purchase'), ('purchase', 'make'), ('make', 'sense'), ('sense', 'compared'), ('compared', 'iphone'), ('iphone', 'reduced'), ('reduced', 'customer'), ('customer', 'expectation'), ('expectation', 'display'), ('display', 'display'), ('display', 'fingerprint'), ('fingerprint', 'scanner'), ('scanner', 'hz'), ('hz', 'refresh'), ('refresh', 'rate'), ('rate', 'hz'), ('hz', 'iphone'), ('iphone', 'model'), ('model', 'india'), ('india', 'paying'), ('paying', 'lot'), ('lot', 'base'), ('base', 'model'), ('model', 'iphone'), ('iphone', 'worth'), ('worth', 'money'), ('money', 'ur'), ('ur', 'bjp'), ('bjp', 'full'), ('full', 'corrupt'), ('corrupt', 'money'), ('money', 'ahead'), ('ahead', 'reading'), ('reading', 'review'), ('review', 'suggest'), ('suggest', 'poor'), (' ...
# ['duplicate iphone', 'iphone camera', 'camera design', 'design changed', 'changed low', 'low quality', 'quality buy', 'buy samsung', 'samsung bigggggg', 'bigggggg bot', 'bot buy', 'buy phoneyou', 'phoneyou iphone', 'iphone pro', 'pro iphone', 'iphone blue', 'blue outlook', 'outlook attractive', 'attractive dim', 'dim usage', 'usage min', 'min fingerprint', 'fingerprint cinematic', 'cinematic video', 'video feature', 'feature iphone', 'iphone charging', 'charging cable', 'cable iphone', 'iphone adapter', 'adapter finally', 'finally iphone', 'iphone experience', 'experience average', 'average hairline', 'hairline scratch', 'scratch visible', 'visible directly', 'directly contacting', 'contacting amazon', 'amazon replacement', 'replacement asked', 'asked connect', 'connect apple', 'apple connected', 'connected apple', 'apple asked', 'asked connect', 'connect amazon', 'amazon blame', 'blame game', 'game begin', 'begin end', 'end paying', 'paying awfull', 'awfull service', 'service tag', 'tag social', 'social medium', 'medium amazon', 'amazon apple', 'apple big', 'big scam', 'scam ignore', 'ignore negative', 'negative comment', 'comment made', 'made amateur', 'amateur reason', 'reason upgrade', 'upgrade camera', 'camera bigger', 'bigger camera', 'camera aperture', 'aperture ois', 'ois cinematic', 'cinematic mode', 'mode low', 'low light', 'light picture', 'picture outstanding', 'outstanding picture', 'picture flower', 'flower night', 'night picture', 'picture daylight', 'daylight reference', 'reference apple', 'apple job', 'job management', 'management giving', 'giving back', 'back processor', 'processor processor', 'processor performance', 'performance software', 'software usual', 'usual strong', 'strong point', 'point iphone', 'iphone io', 'io storage', 'storage forget', 'forget gig', 'gig base', 'base storage', 'storage compared', 'compared gig', 'gig year', 'year base', 'base model', 'model buy', 'buy iphone', 'iphone don', 'don bother', 'bother upgrade', 'upgrade wait', 'wait year', 'year release', 'release iphone', 'iphone previous', 'previous version', 'version surely', 'surely feel', 'feel difference', 'difference gap', 'gap iphone', 'iphone inr', 'inr offer', 'offer present', 'present iphone', 'iphone discount', 'discount hdfc', 'hdfc card', 'card make', 'make actual', 'actual make', 'make sense', 'sense save', 'save buy', 'buy year', 'year iphone', 'iphone upgrading', 'upgrading iphone', 'iphone previous', 'previous version', 'version iphone', 'iphone purchase', 'purchase make', 'make sense', 'sense compared', 'compared iphone', 'iphone reduced', 'reduced customer', 'customer expectation', 'expectation display', 'display display', 'display fingerprint', 'fingerprint scanner', 'scanner hz', 'hz refresh', 'refresh rate', 'rate hz', 'hz iphone', 'iphone model', 'model india', 'india paying', 'paying lot', 'lot base', 'base model', 'model iphone', 'iphone worth', 'worth money', 'money ur', 'ur bjp', 'bjp full', 'full corrupt', 'corrupt money', 'money ahead', 'ahead reading', 'reading review', 'review suggest', 'suggest poor', 'poor afford', 'afford lmao', 'lmao xdxdxdxdxd', 'xdxdxdxdxd money', 'money flex', 'flex buy', 'buy bored', 'bored writing', 'writing review', 'review drinking', 'drinking coffee', 'coffee chemistry', 'chemistry exam', 'exam manday', 'manday study', 'study mole', 'mole concept', 'concept bored', 'bored write', 'write review', 'review read', 'read review', 'review til', 'til justt', 'justt wasted', 'wasted productive', 'productive oneplus', 'oneplus iphone', 'iphone ui', 'ui feel', 'feel iphone', 'iphone mind', 'mind blowing', 'blowing money', 'money dream', 'dream fulfilled', 'fulfilled ve', 've iphone', 'iphone year', 'year problem', 'problem faced', 'faced entire', 'entire lifespan', 'lifespan life', 'life apple', 'apple finally', 'finally broken', 'broken amazing', 'amazing user', 'user experience', 'experience camera', 'camera iphone', 'iphone life', 'life iphone', 'iphone simply', 'simply awesome',  ...

# %%
# Using count vectoriser to view the frequency of bigrams
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(ngram_range=(2, 2))
bag_of_words = vectorizer.fit_transform(dictionary2)
vectorizer.vocabulary_

sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
print(words_freq[:100])
# Out:
# [('medium loaded', 8), ('iphone camera', 4), ('cinematic mode', 4), ('buy iphone', 4), ('previous version', 4), ('year iphone', 4), ('iphone previous', 3), ('make sense', 3), ('refresh rate', 3), ('user experience', 3), ('experience camera', 3), ('iphone user', 3), ('purchasing iphone', 3), ('display camera', 3), ('iphone iphone', 3), ('amazing camera', 3), ('camera design', 2), ('buy samsung', 2), ('iphone pro', 2), ('cinematic video', 2), ('feature iphone', 2), ('iphone adapter', 2), ('iphone experience', 2), ('asked connect', 2), ('upgrade camera', 2), ('base model', 2), ('iphone upgrading', 2), ('version iphone', 2), ('compared iphone', 2), ('fingerprint scanner', 2), ('iphone model', 2), ('model iphone', 2), ('oneplus iphone', 2), ('mind blowing', 2), ('iphone year', 2), ('camera iphone', 2), ('improved camera', 2), ('data transfer', 2), ('happy customer', 2), ('purchased iphone', 2), ('experience iphone', 2), ('feature apple', 2), ('camera feature', 2), ('upgrade iphone', 2), ('camera quality', 2), ('camera simply', 2), ('upgrade bought', 2), ('bought iphone', 2), ('iphone older', 2), ('save life', 2), ('wide angle', 2), ('picture dark', 2), ('hz display', 2), ('brighter display', 2), ('life medium', 2), ('thing cinematic', 2), ('happy purchase', 2), ('purchase camera', 2), ('camera amazing', 2), ('red colour', 2), ('duplicate iphone', 1), ('design changed', 1), ('changed low', 1), ('low quality', 1), ('quality buy', 1), ('samsung bigggggg', 1), ('bigggggg bot', 1), ('bot buy', 1), ('buy phoneyou', 1), ('phoneyou iphone', 1), ('pro iphone', 1), ('iphone blue', 1), ('blue outlook', 1), ('outlook attractive', 1), ('attractive dim', 1), ('dim usage', 1), ('usage min', 1), ('min fingerprint', 1), ('fingerprint cinematic', 1), ('video feature', 1), ('iphone charging', 1), ('charging cable', 1), ('cable iphone', 1), ('adapter finally', 1), ('finally iphone', 1), ('experience average', 1), ('average hairline', 1), ('hairline scratch', 1), ('scratch visible', 1), ('visible directly', 1), ('directly contacting', 1), ('contacting amazon', 1), ('amazon replacement', 1), ('replacement asked', 1), ('connect apple', 1), ('apple connected', 1), ('connected apple', 1), ('apple asked', 1), ('connect amazon', 1), ('amazon blame', 1)]

# %%
# Generating wordcloud
words_dict = dict(words_freq)
WC_height = 1000
WC_width = 1500
WC_max_words = 200
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width, stopwords=new_stopwords)
wordCloud.generate_from_frequencies(words_dict)

plt.figure(4)
plt.title('Most frequently occurring bigrams connected by same colour and font size')
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()
